# %%
import sys
import os
sys.path.append(os.path.abspath("../src"))

import pandas as pd
from analysis import perform_outlier_analysis

df = pd.read_csv("../results/strategy_output.csv")
perform_outlier_analysis(df)

print("Notebook 7 completed successfully ✅")
# Out:
# Performing Outlier Analysis (robust version)...
# No trades found.
# Notebook 7 completed successfully ✅
